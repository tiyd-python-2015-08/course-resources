# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
complaints = pd.read_csv('complaints_dec_2014.csv')

# %%
complaints.Product
# Out:
# 0                Debt collection
# 1                Debt collection
# 2                Debt collection
# 3                Debt collection
# 4                Debt collection
# 5                Debt collection
# 6                    Credit card
# 7                Debt collection
# 8                Debt collection
# 9                Debt collection
# 10               Debt collection
# 11       Bank account or service
# 12               Debt collection
# 13               Debt collection
# 14               Debt collection
# 15               Debt collection
# 16              Credit reporting
# 17               Debt collection
# 18               Debt collection
# 19                   Credit card
# 20       Bank account or service
# 21              Credit reporting
# 22              Credit reporting
# 23                      Mortgage
# 24                      Mortgage
# 25                      Mortgage
# 26               Money transfers
# 27       Bank account or service
# ...

# %%
product_count = complaints.Product.fillna.value_counts()

# %%
product_count.fillna
# Out:
# Mortgage                   3002
# Debt collection            2942
# Credit reporting           2113
# Bank account or service    1136
# Credit card                1100
# Consumer loan               578
# Student loan                340
# Payday loan                 141
# Money transfers             107
# Prepaid card                 70
# Other financial service      14
# dtype: int64

# %%
type(product_count)
# Out:
# pandas.core.series.Series

# %%
product_count.plot(kind='bar')

# %%
company_series = complaints.Company.value_counts()
len(company_series.unique())
# Out:
# 68

# %%
complaints['company_response'] = complaints.drop('Company response')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-9060c81ddca6> in <module>()
# ----> 1 complaints['company_response'] = complaints.drop('Company response')
#
# /Users/james/src/github.com/tiyd-python-2015-08/course-resources/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1595                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1596             else:
# -> 1597                 new_axis = axis.drop(labels, errors=errors)
#    1598             dropped = self.reindex(**{axis_name: new_axis})
#    1599             try:
#
# /Users/james/src/github.com/tiyd-python-2015-08/course-resources/.direnv/python-3.4.3/lib/python3.4/site-packages/pandas/core/index.py in drop(self, labels, errors)
#    2568         if mask.any():
# ...

# %%
complaints = complaints.rename(columns={'Company response': 'company_response'})

# %%
complaints.company_response.value_counts()
# Out:
# Closed with explanation            8185
# Closed with non-monetary relief    1253
# In progress                        1056
# Closed with monetary relief         643
# Closed                              239
# Untimely response                   167
# dtype: int64

# %%
date_complaints = complaints.copy()

# %%
date_series = date_complaints.pop('Date received')

# %%
date_series
# Out:
# 0        12/31/2014
# 1        12/31/2014
# 2        12/31/2014
# 3        12/31/2014
# 4        12/31/2014
# 5        12/31/2014
# 6        12/31/2014
# 7        12/31/2014
# 8        12/31/2014
# 9        12/31/2014
# 10       12/31/2014
# 11       12/31/2014
# 12       12/31/2014
# 13       12/31/2014
# 14       12/31/2014
# 15       12/31/2014
# 16       12/31/2014
# 17       12/31/2014
# 18       12/31/2014
# 19       12/31/2014
# 20       12/31/2014
# 21       12/31/2014
# 22       12/31/2014
# 23       12/31/2014
# 24       12/31/2014
# 25       12/31/2014
# 26       12/31/2014
# 27       12/31/2014
# 28       12/31/2014
# 29       12/31/2014
#             ...
# 11513    12/01/2014
# 11514    12/01/2014
# 11515    12/01/2014
# 11516    12/01/2014
# 11517    12/01/2014
# 11518    12/01/2014
# 11519    12/01/2014
# 11520    12/01/2014
# 11521    12/01/2014
# 11522    12/01/2014
# 11523    12/01/2014
# 11524    12/01/2014
# 11525    12/01/2014
# 11526    12/01/2014
# ...

# %%
date_complaints.index = pd.to_datetime(date_series, format='%m/%d/%Y')

# %%
date_complaints
# Out:
#                Complaint ID                  Product  \
# Date received
# 2014-12-31          1177167          Debt collection
# 2014-12-31          1177166          Debt collection
# 2014-12-31          1177165          Debt collection
# 2014-12-31          1177164          Debt collection
# 2014-12-31          1177163          Debt collection
# 2014-12-31          1177162          Debt collection
# 2014-12-31          1177154              Credit card
# 2014-12-31          1177143          Debt collection
# 2014-12-31          1177140          Debt collection
# 2014-12-31          1177139          Debt collection
# 2014-12-31          1177136          Debt collection
# 2014-12-31          1177128  Bank account or service
# 2014-12-31          1177125          Debt collection
# 2014-12-31          1177124          Debt collection
# 2014-12-31          1177116          Debt collection
# 2014-12-31          1177114          Debt collection
# ...

# %%
date_complaints.index.unique()
# Out:
# DatetimeIndex(['2014-12-31', '2014-12-30', '2014-12-29', '2014-12-28',
#                '2014-12-27', '2014-12-26', '2014-12-25', '2014-12-24',
#                '2014-12-23', '2014-12-22', '2014-12-21', '2014-12-20',
#                '2014-12-19', '2014-12-18', '2014-12-17', '2014-12-16',
#                '2014-12-15', '2014-12-14', '2014-12-13', '2014-12-12',
#                '2014-12-11', '2014-12-10', '2014-12-09', '2014-12-08',
#                '2014-12-07', '2014-12-06', '2014-12-05', '2014-12-04',
#                '2014-12-03', '2014-12-02', '2014-12-01'],
#               dtype='datetime64[ns]', name='Date received', freq=None, tz=None)

# %%
date_complaints['day_of_week'] = date_complaints.index.dayofweek

# %%
date_complaints.head()
# Out:
#                Complaint ID          Product Sub-product  \
# Date received
# 2014-12-31          1177167  Debt collection         NaN
# 2014-12-31          1177166  Debt collection         NaN
# 2014-12-31          1177165  Debt collection         NaN
# 2014-12-31          1177164  Debt collection         NaN
# 2014-12-31          1177163  Debt collection         NaN
#
#                                                Issue         Sub-issue State  \
# Date received
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
#
#                ZIP code Submitted via Date sent to company  \
# Date received
# ...

# %%
date_complaints.day_of_week.value_counts(sort=False).plot(kind='bar')

# %%
date_complaints.day_of_week.value_counts(sort=False)
# Out:
# 0    2544
# 1    2580
# 2    2289
# 3    1634
# 4    1446
# 5     543
# 6     507
# dtype: int64

# %%
date_complaints.head()
date_complaints.replace({'day_of_week': {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}})
# Out:
#                Complaint ID                  Product  \
# Date received
# 2014-12-31          1177167          Debt collection
# 2014-12-31          1177166          Debt collection
# 2014-12-31          1177165          Debt collection
# 2014-12-31          1177164          Debt collection
# 2014-12-31          1177163          Debt collection
# 2014-12-31          1177162          Debt collection
# 2014-12-31          1177154              Credit card
# 2014-12-31          1177143          Debt collection
# 2014-12-31          1177140          Debt collection
# 2014-12-31          1177139          Debt collection
# 2014-12-31          1177136          Debt collection
# 2014-12-31          1177128  Bank account or service
# 2014-12-31          1177125          Debt collection
# 2014-12-31          1177124          Debt collection
# 2014-12-31          1177116          Debt collection
# 2014-12-31          1177114          Debt collection
# ...

# %%
date_complaints.replace({'day_of_week': 
                         {0: 'Monday', 
                          1: 'Tuesday', 
                          2: 'Wednesday', 
                          3: 'Thursday', 
                          4: 'Friday', 
                          5: 'Saturday', 
                          6: 'Sunday'}}) \
               .day_of_week.value_counts(sort=False).plot(kind='bar')

# %%
date_complaints.replace({'day_of_week': 
                         {0: 'Monday', 
                          1: 'Tuesday', 
                          2: 'Wednesday', 
                          3: 'Thursday', 
                          4: 'Friday', 
                          5: 'Saturday', 
                          6: 'Sunday'}}) \
               .day_of_week.value_counts(sort=False)
# Out:
# Saturday      543
# Sunday        507
# Wednesday    2289
# Tuesday      2580
# Monday       2544
# Thursday     1634
# Friday       1446
# dtype: int64

# %%
date_complaints.day_of_week.value_counts(sort=False).plot(kind='bar')

# %%
date_counts = date_complaints['Complaint ID'].resample('d', how=['count'])

# %%
date_counts['weekday'] = date_counts.index.weekday

# %%
date_counts
# Out:
#                count  weekday
# Date received
# 2014-12-01       474        0
# 2014-12-02       516        1
# 2014-12-03       494        2
# 2014-12-04       571        3
# 2014-12-05       426        4
# 2014-12-06       147        5
# 2014-12-07       117        6
# 2014-12-08       526        0
# 2014-12-09       503        1
# 2014-12-10       570        2
# 2014-12-11       484        3
# 2014-12-12       428        4
# 2014-12-13       144        5
# 2014-12-14       130        6
# 2014-12-15       475        0
# 2014-12-16       510        1
# 2014-12-17       539        2
# 2014-12-18       527        3
# 2014-12-19       363        4
# 2014-12-20       148        5
# 2014-12-21        96        6
# 2014-12-22       537        0
# 2014-12-23       501        1
# 2014-12-24       315        2
# 2014-12-25        52        3
# 2014-12-26       229        4
# 2014-12-27       104        5
# 2014-12-28       164        6
# 2014-12-29       532        0
# ...

# %%
len(date_counts[date_counts.weekday == 0])
# Out:
# 5

# %%
date_counts[date_counts.weekday == 0].mean()
# Out:
# count      508.8
# weekday      0.0
# dtype: float64

# %%
date_counts[date_counts.weekday == 0]
# Out:
#                count  weekday
# Date received
# 2014-12-01       474        0
# 2014-12-08       526        0
# 2014-12-15       475        0
# 2014-12-22       537        0
# 2014-12-29       532        0

# %%
res = [date_counts[date_counts.weekday == x].mean()['count'] for x in range(7)]

# %%
pd.DataFrame(res).rename(columns={0: 'mean'}).plot(kind='bar')
